# %% [markdown]
# # **Step 1: Importing Dataset from Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# selecting the dataset folder
# !ls '/content/drive/My Drive/yolo'
# Out:
# custom_weight  darknet	Mask_Dataset  Mask_Dataset.zip

# %%
#unzipping the file
#!unzip '/content/drive/My Drive/yolo/Mask_Dataset.zip' -d '/content/drive/My Drive/yolo/'

# %% [markdown]
# # **Step 2: Setting up the Darknet**

# %%
#cloning the darknet
#!git clone 'https://github.com/AlexeyAB/darknet' '/content/drive/My Drive/yolo/darknet'

# %%
# %cd '/content/drive/My Drive/yolo/darknet'
# Out:
# /content/drive/My Drive/yolo/darknet

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %% [markdown]
# # **Step 3: Training and testing the data**

# %%
# %cd '/content/drive/My Drive/yolo'
# Out:
# /content/drive/My Drive/yolo

# %%
# !python Mask_Dataset/creating-files-data-and-name.py

# %%
# !python Mask_Dataset/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet detector train Mask_Dataset/labelled_data.data darknet/cfg/yolov4_custom.cfg custom_weight/yolov4.conv.137 -dont_show -map
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 398338, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.968577), count: 2, class_loss = 0.000001, iou_loss = 0.474991, total_loss = 0.474992
#  total_bbox = 398340, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...
